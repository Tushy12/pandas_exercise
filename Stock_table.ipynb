# %%
key = 'ABCDEFGHI'

# %%
import numpy as np
import pandas as pd
import os

# package to extract data from various Internet sources into a DataFrame
# make sure you have it installed
import pandas_datareader.data as web

import datetime as dt
import seaborn as sns

# %%
df = web.DataReader("AAPL", "av-daily", start='1/1/2015',
                   end='1/1/2021',api_key='key')

# %%
df['stock'] = 'AAPL'

# %%
df
# Out:
#               open     high       low   close     volume stock
# 2015-01-02  111.39  111.440  107.3500  109.33   53204626  AAPL
# 2015-01-05  108.29  108.650  105.4100  106.25   64285491  AAPL
# 2015-01-06  106.54  107.430  104.6300  106.26   65797116  AAPL
# 2015-01-07  107.20  108.200  106.6950  107.75   40105934  AAPL
# 2015-01-08  109.23  112.150  108.7000  111.89   59364547  AAPL
# ...            ...      ...       ...     ...        ...   ...
# 2020-12-24  131.32  133.460  131.1000  131.97   54930064  AAPL
# 2020-12-28  133.99  137.340  133.5100  136.69  123124632  AAPL
# 2020-12-29  138.05  138.789  134.3409  134.87  121047324  AAPL
# 2020-12-30  135.58  135.990  133.4000  133.72   96452124  AAPL
# 2020-12-31  134.08  134.740  131.7200  132.69   99116586  AAPL
#
# [1511 rows x 6 columns]

# %%
df1 = web.DataReader("TSLA", "av-daily", start='1/1/2015',
                   end='1/1/2021',api_key='key')
df1['stock'] = 'TSLA'
df1
# Out:
#               open      high       low    close    volume stock
# 2015-01-02  222.87  223.2500  213.2600  219.310   4764443  TSLA
# 2015-01-05  214.55  216.5000  207.1626  210.090   5368477  TSLA
# 2015-01-06  210.06  214.2000  204.2100  211.280   6261936  TSLA
# 2015-01-07  213.35  214.7800  209.7800  210.950   2968390  TSLA
# 2015-01-08  212.81  213.7999  210.0100  210.615   3442509  TSLA
# ...            ...       ...       ...      ...       ...   ...
# 2020-12-24  642.99  666.0900  641.0000  661.770  22865568  TSLA
# 2020-12-28  674.51  681.4000  660.8000  663.690  31553561  TSLA
# 2020-12-29  661.00  669.9000  655.0000  665.990  22910811  TSLA
# 2020-12-30  672.00  696.6000  668.3603  694.780  42846021  TSLA
# 2020-12-31  699.99  718.7200  691.1200  705.670  49649928  TSLA
#
# [1511 rows x 6 columns]

# %%
df2 = web.DataReader("IBM", "av-daily", start='1/1/2015',
                   end='1/1/2021',api_key='key')
df2['stock'] = 'IBM'
df2
# Out:
#               open     high     low   close   volume stock
# 2015-01-02  161.31  163.310  161.00  162.06  5525341   IBM
# 2015-01-05  161.27  161.270  159.19  159.51  4880389   IBM
# 2015-01-06  159.67  159.960  155.17  156.07  6145670   IBM
# 2015-01-07  157.20  157.200  154.03  155.05  4701015   IBM
# 2015-01-08  156.24  159.044  155.55  158.42  4240585   IBM
# ...            ...      ...     ...     ...      ...   ...
# 2020-12-24  125.00  125.100  124.21  124.69  1761122   IBM
# 2020-12-28  125.10  126.600  124.46  124.82  3583222   IBM
# 2020-12-29  125.35  125.480  123.24  123.80  3487007   IBM
# 2020-12-30  123.80  124.850  123.63  124.34  3380494   IBM
# 2020-12-31  124.22  126.030  123.99  125.88  3574696   IBM
#
# [1511 rows x 6 columns]

# %%
df3 = web.DataReader("MSFT", "av-daily", start='1/1/2015',
                   end='1/1/2021',api_key='key')
df3['stock'] = 'MSFT'
df3
# Out:
#               open      high     low    close    volume stock
# 2015-01-02   46.66   47.4200   46.54   46.760  27913852  MSFT
# 2015-01-05   46.37   46.7300   46.25   46.325  39673865  MSFT
# 2015-01-06   46.38   46.7490   45.54   45.650  36447854  MSFT
# 2015-01-07   45.98   46.4600   45.49   46.230  29114061  MSFT
# 2015-01-08   46.75   47.7499   46.72   47.590  29645202  MSFT
# ...            ...       ...     ...      ...       ...   ...
# 2020-12-24  221.42  223.6100  221.20  222.750  10550572  MSFT
# 2020-12-28  224.45  226.0300  223.02  224.960  17762701  MSFT
# 2020-12-29  226.31  227.1800  223.58  224.150  17403213  MSFT
# 2020-12-30  225.23  225.6300  221.47  221.680  20272337  MSFT
# 2020-12-31  221.70  223.0000  219.68  222.420  20942132  MSFT
#
# [1511 rows x 6 columns]

# %%
all_data = pd.concat([df,df1,df2,df3], ignore_index=False)

# %%
all_data
# Out:
#               open    high      low   close    volume stock
# 2015-01-02  111.39  111.44  107.350  109.33  53204626  AAPL
# 2015-01-05  108.29  108.65  105.410  106.25  64285491  AAPL
# 2015-01-06  106.54  107.43  104.630  106.26  65797116  AAPL
# 2015-01-07  107.20  108.20  106.695  107.75  40105934  AAPL
# 2015-01-08  109.23  112.15  108.700  111.89  59364547  AAPL
# ...            ...     ...      ...     ...       ...   ...
# 2020-12-24  221.42  223.61  221.200  222.75  10550572  MSFT
# 2020-12-28  224.45  226.03  223.020  224.96  17762701  MSFT
# 2020-12-29  226.31  227.18  223.580  224.15  17403213  MSFT
# 2020-12-30  225.23  225.63  221.470  221.68  20272337  MSFT
# 2020-12-31  221.70  223.00  219.680  222.42  20942132  MSFT
#
# [6044 rows x 6 columns]

# %%
all_data.set_index('stock',append=True, inplace=True)
all_data
# Out:
#                     open    high      low   close    volume
#            stock
# 2015-01-02 AAPL   111.39  111.44  107.350  109.33  53204626
# 2015-01-05 AAPL   108.29  108.65  105.410  106.25  64285491
# 2015-01-06 AAPL   106.54  107.43  104.630  106.26  65797116
# 2015-01-07 AAPL   107.20  108.20  106.695  107.75  40105934
# 2015-01-08 AAPL   109.23  112.15  108.700  111.89  59364547
# ...                  ...     ...      ...     ...       ...
# 2020-12-24 MSFT   221.42  223.61  221.200  222.75  10550572
# 2020-12-28 MSFT   224.45  226.03  223.020  224.96  17762701
# 2020-12-29 MSFT   226.31  227.18  223.580  224.15  17403213
# 2020-12-30 MSFT   225.23  225.63  221.470  221.68  20272337
# 2020-12-31 MSFT   221.70  223.00  219.680  222.42  20942132
#
# [6044 rows x 5 columns]

# %%
vol = all_data.drop(columns=['open','high','low','close'])
vol
# Out:
#                     volume
#            stock
# 2015-01-02 AAPL   53204626
# 2015-01-05 AAPL   64285491
# 2015-01-06 AAPL   65797116
# 2015-01-07 AAPL   40105934
# 2015-01-08 AAPL   59364547
# ...                    ...
# 2020-12-24 MSFT   10550572
# 2020-12-28 MSFT   17762701
# 2020-12-29 MSFT   17403213
# 2020-12-30 MSFT   20272337
# 2020-12-31 MSFT   20942132
#
# [6044 rows x 1 columns]

# %%
all_data_plot = pd.concat([df,df1,df2,df3], ignore_index=False)
sns.lineplot(data=all_data_plot,x=all_data_plot.index, y='close', palette='husl', hue='stock',
             )
# Out:
# <AxesSubplot:ylabel='close'>

# %%
all_data_plot['index'] = range(1,6045)

# %%
year = all_data_plot.index

# %%
all_data_plot.set_index('index', inplace=True)
all_data_plot['Year'] = year
all_data_plot
# Out:
#          open    high      low   close    volume stock        Year
# index
# 1      111.39  111.44  107.350  109.33  53204626  AAPL  2015-01-02
# 2      108.29  108.65  105.410  106.25  64285491  AAPL  2015-01-05
# 3      106.54  107.43  104.630  106.26  65797116  AAPL  2015-01-06
# 4      107.20  108.20  106.695  107.75  40105934  AAPL  2015-01-07
# 5      109.23  112.15  108.700  111.89  59364547  AAPL  2015-01-08
# ...       ...     ...      ...     ...       ...   ...         ...
# 6040   221.42  223.61  221.200  222.75  10550572  MSFT  2020-12-24
# 6041   224.45  226.03  223.020  224.96  17762701  MSFT  2020-12-28
# 6042   226.31  227.18  223.580  224.15  17403213  MSFT  2020-12-29
# 6043   225.23  225.63  221.470  221.68  20272337  MSFT  2020-12-30
# 6044   221.70  223.00  219.680  222.42  20942132  MSFT  2020-12-31
#
# [6044 rows x 7 columns]

# %%
vol = all_data_plot.drop(columns=['open','high','low','close'])
vol['Year'] = pd.to_datetime(vol['Year'])
vol['Week'] = vol['Year'].dt.isocalendar().week
vol.head(50)
# Out:
#           volume stock       Year  Week
# index
# 1       53204626  AAPL 2015-01-02     1
# 2       64285491  AAPL 2015-01-05     2
# 3       65797116  AAPL 2015-01-06     2
# 4       40105934  AAPL 2015-01-07     2
# 5       59364547  AAPL 2015-01-08     2
# 6       53315099  AAPL 2015-01-09     2
# 7       49650790  AAPL 2015-01-12     3
# 8       67091928  AAPL 2015-01-13     3
# 9       48956588  AAPL 2015-01-14     3
# 10      60013996  AAPL 2015-01-15     3
# 11      78513345  AAPL 2015-01-16     3
# 12      49899907  AAPL 2015-01-20     4
# 13      48575897  AAPL 2015-01-21     4
# 14      53796409  AAPL 2015-01-22     4
# 15      46464828  AAPL 2015-01-23     4
# 16      55614979  AAPL 2015-01-26     5
# 17      95568749  AAPL 2015-01-27     5
# 18     146477063  AAPL 2015-01-28     5
# 19      84436432  AAPL 2015-01-29     5
# 20      83745461  AAPL 2015-01-30     5
# 21      62739100  AAPL 2015-02-02     6
# 22      51915749  AAPL 2015-02-03     6
# ...

# %%
table = pd.pivot_table(vol, values='volume', index=['Year','Week'],
                       columns=['stock'], aggfunc=np.sum)

# %%
table
# Out:
# stock                 AAPL      IBM      MSFT      TSLA
# Year       Week
# 2015-01-02 1      53204626  5525341  27913852   4764443
# 2015-01-05 2      64285491  4880389  39673865   5368477
# 2015-01-06 2      65797116  6145670  36447854   6261936
# 2015-01-07 2      40105934  4701015  29114061   2968390
# 2015-01-08 2      59364547  4240585  29645202   3442509
# ...                    ...      ...       ...       ...
# 2020-12-24 52     54930064  1761122  10550572  22865568
# 2020-12-28 53    123124632  3583222  17762701  31553561
# 2020-12-29 53    121047324  3487007  17403213  22910811
# 2020-12-30 53     96452124  3380494  20272337  42846021
# 2020-12-31 53     99116586  3574696  20942132  49649928
#
# [1511 rows x 4 columns]
